# %% [markdown]
# <a href="https://colab.research.google.com/github/JaviLaura/Airbnb_Bookings-pandas-/blob/main/Airbnb_Bookings.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #<img src="https://static.junilearning.com/images/juni_logo.png" height=75 align=center hspace="5px"> **DS3 Airbnb Bookings**

# %% [markdown]
# You have been contracted to do seasonal work in Los Angeles during the Summer / Winter and are looking for flexible housing. You decide to explore listings on Airbnb and first need to decide whether to rent a room or an entire home / apartment. You first want to see the difference in the number of reviews between private rooms versus entire homes. Begin by importing the CSV dataset into a DataFrame and getting the mean number of reviews for entire homes and for private rooms.
#
# Dataset: https://static.junilearning.com/python_data_science/airbnb_listings.csv

# %%
import pandas as pd
originalDF = pd.read_csv('https://static.junilearning.com/python_data_science/airbnb_listings.csv')
display(originalDF)

meanVar1 = originalDF.groupby('room_type').mean()['number_of_reviews']

display(meanVar1)
# Out:
#              id                                               name    host_id  \
# 0           109  Amazing bright elegant condo park front *UPGRA...        521
# 1          2708  Runyon Canyon  | Beau Furn Mir Mini-Suite Fire...       3008
# 2          2732                              Zen Life at the Beach       3041
# 3          2864             * Beautiful Master Suite/Jacuzzi Tub/*       3207
# 4          5728    Tiny Home in Artistic Oasis near Venice and LAX       9171
# ...         ...                                                ...        ...
# 31895  48070933                 clean and comfortable room to rest  387568794
# 31896  48070985                               quiet and clean room  387568794
# 31897  48071306  LOWER PRICE and Deep Cleaning+Pool+Free Parkin...  106941010
# 31898  48071488                           Historical Mansion Hotel    8402388
# 31899  48072320                                    Happy home 快乐之家   45258263
#
#             host_name   neighbourhood_group    neighbourhood  latitude  \
# 0               Paolo          Other Cities      Culver City  33.98209
# 1               Chas.   City of Los Angeles        Hollywood  34.09768
# 2      Yoga Priestess          Other Cities     Santa Monica  34.00475
# 3           Bernadine          Other Cities       Bellflower  33.87619
# 4               Sanni   City of Los Angeles          Del Rey  33.98750
# ...               ...                   ...              ...       ...
# 31895          Sergio  Unincorporated Areas  Rowland Heights  33.98763
# 31896          Sergio  Unincorporated Areas  Rowland Heights  33.98740
# 31897           Linda   City of Los Angeles         Westwood  34.06114
# 31898         Jessica          Other Cities         Glendora  34.15155
# 31899            Zhou          Other Cities          Arcadia  34.10909
#
#        longitude        room_type  price  minimum_nights  number_of_reviews  \
# 0     -118.38494  Entire home/apt    115              30                  2
# 1     -118.34602     Private room     71              30                 28
# 2     -118.48127     Private room    155               1                 21
# 3     -118.11397  Entire home/apt     50              30                  0
# 4     -118.43200     Private room     42              30                310
# ...          ...              ...    ...             ...                ...
# 31895 -117.88529     Private room     36               1                  0
# 31896 -117.88588     Private room     28               1                  0
# 31897 -118.44367  Entire home/apt    176               1                  0
# 31898 -117.87664  Entire home/apt    195               1                  0
# 31899 -118.05121     Private room     45               7                  0
#
#       last_review  reviews_per_month  calculated_host_listings_count  \
# 0      2016-05-15               0.02                               1
# 1      2020-11-08               0.34                               2
# 2      2019-12-27               0.18                               2
# 3             NaN                NaN                               1
# 4      2020-04-29               2.20                               4
# ...           ...                ...                             ...
# 31895         NaN                NaN                               3
# 31896         NaN                NaN                               3
# 31897         NaN                NaN                              13
# 31898         NaN                NaN                               5
# 31899         NaN                NaN                               2
#
#        availability_365
# 0                     0
# 1                   315
# 2                   365
# 3                     0
# 4                     1
# ...                 ...
# 31895               180
# 31896               179
# 31897               270
# 31898               362
# 31899               343
#
# [31900 rows x 16 columns]
# room_type
# Entire home/apt    36.707446
# Hotel room         34.310345
# Private room       29.741913
# Shared room         7.125234
# Name: number_of_reviews, dtype: float64

# %% [markdown]
# From our previous findings we found that entire homes have more reviews on average than private rooms, indicating that they're more popular. Now that you've decided to rent an entire home, you next want to identify listings that meet your requirements. Your requirements are: `price < $200`, `location = Hollywood`, `minimum nights = 30`, `reviews = 10`, and `availability = 200`. Output a DataFrame with entire home listings that meet these requirements.

# %%
filteredData = originalDF[(originalDF['price'] < 200) & (originalDF['neighbourhood'] == 'Hollywood') & (originalDF['minimum_nights'] >= 30) & (originalDF['number_of_reviews'] >= 10) & (originalDF['availability_365'] >= 200)]

display(filteredData)
# Out:
#              id                                               name    host_id  \
# 1          2708  Runyon Canyon  | Beau Furn Mir Mini-Suite Fire...       3008
# 7          6931  Run Runyon | Beau Furn Rm  Dres Rm/Wlk-In Clst...       3008
# 53        44062                   Heart of Hollywood- The Original     192939
# 204      255656                      Classic Central Hollywood Gem    1343997
# 205      255701                 Lovely Hollywd Apt-w/ porch&garden    1343997
# ...         ...                                                ...        ...
# 24070  42175893      COZY PRIVATE STUDIO IN THE HEART OF HOLLYWOOD  160918393
# 27096  45252812       Heart ❤️ of Hollywood large room studio-like  365609415
# 27206  45312439      Beautiful Cozy Studio close to Hollywood Blvd  246707001
# 27461  45454343      Gorgeous Hollywood Home - Close to Everything  161515324
# 28328  45896817  SUNSET & HIGHLAND private home backyard & parking  177181598
#
#                host_name  neighbourhood_group neighbourhood  latitude  \
# 1                  Chas.  City of Los Angeles     Hollywood  34.09768
# 7                  Chas.  City of Los Angeles     Hollywood  34.09521
# 53                  Lisa  City of Los Angeles     Hollywood  34.09179
# 204            Hollywood  City of Los Angeles     Hollywood  34.10336
# 205            Hollywood  City of Los Angeles     Hollywood  34.10336
# ...                  ...                  ...           ...       ...
# 24070         West Coast  City of Los Angeles     Hollywood  34.09291
# 27096             Verane  City of Los Angeles     Hollywood  34.09600
# 27206               Loft  City of Los Angeles     Hollywood  34.09392
# 27461  Deshawn And Nancy  City of Los Angeles     Hollywood  34.08630
# 28328             Aurora  City of Los Angeles     Hollywood  34.09576
#
#        longitude        room_type  price  minimum_nights  number_of_reviews  \
# 1     -118.34602     Private room     71              30                 28
# 7     -118.34801     Private room     71              30                 24
# 53    -118.33111  Entire home/apt    125              31                 93
# 204   -118.32366  Entire home/apt    110              30                 22
# 205   -118.32366  Entire home/apt    115              30                 26
# ...          ...              ...    ...             ...                ...
# 24070 -118.32421  Entire home/apt    120              30                 10
# 27096 -118.33800      Shared room     45              30                 22
# 27206 -118.32482  Entire home/apt     89              30                 10
# 27461 -118.31202  Entire home/apt    105              30                 16
# 28328 -118.33828  Entire home/apt    174              30                 10
#
#       last_review  reviews_per_month  calculated_host_listings_count  \
# 1      2020-11-08               0.34                               2
# 7      2021-01-15               0.17                               2
# 53     2020-01-04               0.77                               3
# 204    2020-10-26               0.21                               6
# 205    2020-03-08               0.23                               6
# ...           ...                ...                             ...
# 24070  2020-12-28               0.85                               4
# 27096  2020-11-22               4.20                               2
# 27206  2020-12-04               2.14                               2
# 27461  2021-01-25               3.58                               7
# 28328  2021-01-24               3.19                               2
#
#        availability_365
# 1                   315
# 7                   260
# 53                  364
# 204                 365
# 205                 358
# ...                 ...
# 24070               334
# 27096               307
# 27206               365
# 27461               277
# 28328               330
#
# [167 rows x 16 columns]

# %%
filteredData = originalDF[(originalDF['price'] < 200) & (originalDF['neighbourhood'] == 'Hollywood')] 
filteredData = filteredData[(filteredData['minimum_nights'] >= 30) & (filteredData['number_of_reviews'] >= 10) & (filteredData['availability_365'] >= 200)]
display(filteredData)
# Out:
#              id                                               name    host_id  \
# 1          2708  Runyon Canyon  | Beau Furn Mir Mini-Suite Fire...       3008
# 7          6931  Run Runyon | Beau Furn Rm  Dres Rm/Wlk-In Clst...       3008
# 53        44062                   Heart of Hollywood- The Original     192939
# 204      255656                      Classic Central Hollywood Gem    1343997
# 205      255701                 Lovely Hollywd Apt-w/ porch&garden    1343997
# ...         ...                                                ...        ...
# 24070  42175893      COZY PRIVATE STUDIO IN THE HEART OF HOLLYWOOD  160918393
# 27096  45252812       Heart ❤️ of Hollywood large room studio-like  365609415
# 27206  45312439      Beautiful Cozy Studio close to Hollywood Blvd  246707001
# 27461  45454343      Gorgeous Hollywood Home - Close to Everything  161515324
# 28328  45896817  SUNSET & HIGHLAND private home backyard & parking  177181598
#
#                host_name  neighbourhood_group neighbourhood  latitude  \
# 1                  Chas.  City of Los Angeles     Hollywood  34.09768
# 7                  Chas.  City of Los Angeles     Hollywood  34.09521
# 53                  Lisa  City of Los Angeles     Hollywood  34.09179
# 204            Hollywood  City of Los Angeles     Hollywood  34.10336
# 205            Hollywood  City of Los Angeles     Hollywood  34.10336
# ...                  ...                  ...           ...       ...
# 24070         West Coast  City of Los Angeles     Hollywood  34.09291
# 27096             Verane  City of Los Angeles     Hollywood  34.09600
# 27206               Loft  City of Los Angeles     Hollywood  34.09392
# 27461  Deshawn And Nancy  City of Los Angeles     Hollywood  34.08630
# 28328             Aurora  City of Los Angeles     Hollywood  34.09576
#
#        longitude        room_type  price  minimum_nights  number_of_reviews  \
# 1     -118.34602     Private room     71              30                 28
# 7     -118.34801     Private room     71              30                 24
# 53    -118.33111  Entire home/apt    125              31                 93
# 204   -118.32366  Entire home/apt    110              30                 22
# 205   -118.32366  Entire home/apt    115              30                 26
# ...          ...              ...    ...             ...                ...
# 24070 -118.32421  Entire home/apt    120              30                 10
# 27096 -118.33800      Shared room     45              30                 22
# 27206 -118.32482  Entire home/apt     89              30                 10
# 27461 -118.31202  Entire home/apt    105              30                 16
# 28328 -118.33828  Entire home/apt    174              30                 10
#
#       last_review  reviews_per_month  calculated_host_listings_count  \
# 1      2020-11-08               0.34                               2
# 7      2021-01-15               0.17                               2
# 53     2020-01-04               0.77                               3
# 204    2020-10-26               0.21                               6
# 205    2020-03-08               0.23                               6
# ...           ...                ...                             ...
# 24070  2020-12-28               0.85                               4
# 27096  2020-11-22               4.20                               2
# 27206  2020-12-04               2.14                               2
# 27461  2021-01-25               3.58                               7
# 28328  2021-01-24               3.19                               2
#
#        availability_365
# 1                   315
# 7                   260
# 53                  364
# 204                 365
# 205                 358
# ...                 ...
# 24070               334
# 27096               307
# 27206               365
# 27461               277
# 28328               330
#
# [167 rows x 16 columns]

# %% [markdown]
# Now we want to pick the best listing that meets our requirements. Most importantly we want to rank the listings according to lowest price and least reviews per month (which helps us figure out if it's available often). Now let's grab the columns of price and reviews per month and output the summary statistics for each.

# %%
reviews_col = filteredData['reviews_per_month']
price_col = filteredData['price']
display(reviews_col.describe())
display(price_col.describe())
# Out:
# count    167.000000
# mean       1.594611
# std        1.392229
# min        0.130000
# 25%        0.540000
# 50%        1.210000
# 75%        2.150000
# max        6.090000
# Name: reviews_per_month, dtype: float64
# count    167.000000
# mean      94.317365
# std       36.721205
# min       35.000000
# 25%       69.000000
# 50%       89.000000
# 75%      119.500000
# max      199.000000
# Name: price, dtype: float64

# %%
display(filteredData)
# Out:
#              id                                               name    host_id  \
# 1          2708  Runyon Canyon  | Beau Furn Mir Mini-Suite Fire...       3008
# 7          6931  Run Runyon | Beau Furn Rm  Dres Rm/Wlk-In Clst...       3008
# 53        44062                   Heart of Hollywood- The Original     192939
# 204      255656                      Classic Central Hollywood Gem    1343997
# 205      255701                 Lovely Hollywd Apt-w/ porch&garden    1343997
# ...         ...                                                ...        ...
# 24070  42175893      COZY PRIVATE STUDIO IN THE HEART OF HOLLYWOOD  160918393
# 27096  45252812       Heart ❤️ of Hollywood large room studio-like  365609415
# 27206  45312439      Beautiful Cozy Studio close to Hollywood Blvd  246707001
# 27461  45454343      Gorgeous Hollywood Home - Close to Everything  161515324
# 28328  45896817  SUNSET & HIGHLAND private home backyard & parking  177181598
#
#                host_name  neighbourhood_group neighbourhood  latitude  \
# 1                  Chas.  City of Los Angeles     Hollywood  34.09768
# 7                  Chas.  City of Los Angeles     Hollywood  34.09521
# 53                  Lisa  City of Los Angeles     Hollywood  34.09179
# 204            Hollywood  City of Los Angeles     Hollywood  34.10336
# 205            Hollywood  City of Los Angeles     Hollywood  34.10336
# ...                  ...                  ...           ...       ...
# 24070         West Coast  City of Los Angeles     Hollywood  34.09291
# 27096             Verane  City of Los Angeles     Hollywood  34.09600
# 27206               Loft  City of Los Angeles     Hollywood  34.09392
# 27461  Deshawn And Nancy  City of Los Angeles     Hollywood  34.08630
# 28328             Aurora  City of Los Angeles     Hollywood  34.09576
#
#        longitude        room_type  price  minimum_nights  number_of_reviews  \
# 1     -118.34602     Private room     71              30                 28
# 7     -118.34801     Private room     71              30                 24
# 53    -118.33111  Entire home/apt    125              31                 93
# 204   -118.32366  Entire home/apt    110              30                 22
# 205   -118.32366  Entire home/apt    115              30                 26
# ...          ...              ...    ...             ...                ...
# 24070 -118.32421  Entire home/apt    120              30                 10
# 27096 -118.33800      Shared room     45              30                 22
# 27206 -118.32482  Entire home/apt     89              30                 10
# 27461 -118.31202  Entire home/apt    105              30                 16
# 28328 -118.33828  Entire home/apt    174              30                 10
#
#       last_review  reviews_per_month  calculated_host_listings_count  \
# 1      2020-11-08               0.34                               2
# 7      2021-01-15               0.17                               2
# 53     2020-01-04               0.77                               3
# 204    2020-10-26               0.21                               6
# 205    2020-03-08               0.23                               6
# ...           ...                ...                             ...
# 24070  2020-12-28               0.85                               4
# 27096  2020-11-22               4.20                               2
# 27206  2020-12-04               2.14                               2
# 27461  2021-01-25               3.58                               7
# 28328  2021-01-24               3.19                               2
#
#        availability_365
# 1                   315
# 7                   260
# 53                  364
# 204                 365
# 205                 358
# ...                 ...
# 24070               334
# 27096               307
# 27206               365
# 27461               277
# 28328               330
#
# [167 rows x 16 columns]

# %%
filteredDataNew = filteredData[(filteredData['price'] < 69) & (filteredData['reviews_per_month'] < .54)]
display(filteredDataNew)
# Out:
#             id                                               name   host_id  \
# 1056   1628111                      Beautiful Studio in Hollywood   7089643
# 1094   1687458                     The heart of Hollywood, Studio   8917310
# 1177   1819106                     Private Room with a Double Bed   9250479
# 1364   2181661                     Heart of Hollywood,Full Studio   8917310
# 1366   2181871                  Studio in Hollywood, with parking   7089643
# 2675   5135865                     Hollywood, Studio with parking   7089643
# 2678   5136071                     The heart of Hollywood, Studio   8917310
# 2939   5806781                Spacious Room in Heart of Hollywood   7288044
# 4144   8570560                Private Bathroom Big Master Bedroom  11524850
# 4515   9321531                 Orange Drive Hostel-Male Dorm Room   9250479
# 5153  10912142           Remodeled Greek Style apt (private room)  28005117
# 5178  10974870  Private room with private entrance-Greek Style...  28005117
# 5241  11167198                   Large room in Heart of Hollywood  58096955
# 5844  12549742                 Charming house 4 with free parking  66206065
#
#       host_name  neighbourhood_group neighbourhood  latitude  longitude  \
# 1056    Roseman  City of Los Angeles     Hollywood  34.09972 -118.33787
# 1094       Eyal  City of Los Angeles     Hollywood  34.09770 -118.33686
# 1177        NaN  City of Los Angeles     Hollywood  34.10236 -118.34151
# 1364       Eyal  City of Los Angeles     Hollywood  34.09985 -118.33815
# 1366    Roseman  City of Los Angeles     Hollywood  34.09960 -118.33722
# 2675    Roseman  City of Los Angeles     Hollywood  34.09781 -118.33793
# 2678       Eyal  City of Los Angeles     Hollywood  34.09831 -118.33676
# 2939       Kate  City of Los Angeles     Hollywood  34.10310 -118.33167
# 4144  Alexander  City of Los Angeles     Hollywood  34.09914 -118.31068
# 4515        NaN  City of Los Angeles     Hollywood  34.10296 -118.34076
# 5153      Cihan  City of Los Angeles     Hollywood  34.08757 -118.31347
# 5178      Cihan  City of Los Angeles     Hollywood  34.08783 -118.31056
# 5241      Annie  City of Los Angeles     Hollywood  34.10338 -118.34288
# 5844   Angelica  City of Los Angeles     Hollywood  34.08834 -118.31472
#
#             room_type  price  minimum_nights  number_of_reviews last_review  \
# 1056  Entire home/apt     59              31                 28  2020-07-31
# 1094  Entire home/apt     54              31                 34  2021-01-09
# 1177     Private room     65              30                 14  2017-06-10
# 1364  Entire home/apt     59              31                 22  2020-12-31
# 1366  Entire home/apt     50              31                 32  2020-08-01
# 2675  Entire home/apt     54              31                 36  2020-09-26
# 2678  Entire home/apt     54              31                 13  2020-11-22
# 2939     Private room     55              30                 26  2016-03-15
# 4144     Private room     60              30                 28  2020-11-30
# 4515      Shared room     40              30                 18  2020-02-08
# 5153     Private room     44              30                 10  2019-11-02
# 5178     Private room     42              30                 13  2019-12-09
# 5241     Private room     61              30                 16  2019-10-22
# 5844     Private room     35              30                 10  2019-09-02
#
#       reviews_per_month  calculated_host_listings_count  availability_365
# 1056               0.31                               5               307
# 1094               0.39                               5               359
# 1177               0.19                              20               365
# 1364               0.26                               5               306
# 1366               0.38                               5               313
# 2675               0.49                               5               342
# 2678               0.18                               5               359
# 2939               0.36                               1               365
# 4144               0.44                               9               365
# 4515               0.29                              20               365
# 5153               0.17                               6               365
# 5178               0.28                               6               365
# 5241               0.27                               1               365
# 5844               0.22                               3               365

# %% [markdown]
# Finally let's filter our DataFrame to only include prices and reviews in the first quartile. Then decide on the ID number of the best two listings and type the ID's in the text box below.

# %%
1687458
5135865
# Out:
# 5135865

# %% [markdown]
# Best Listings ID's -
